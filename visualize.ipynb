# %%
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import os

# Load the labels CSV
labels_df = pd.read_csv('cifar-10/trainLabels.csv')
print(labels_df.head(10))
print(f"\nTotal images: {len(labels_df)}")
print(f"\nUnique classes: {labels_df['label'].unique()}")
# Out:
#    id       label
# 0   1        frog
# 1   2       truck
# 2   3       truck
# 3   4        deer
# 4   5  automobile
# 5   6  automobile
# 6   7        bird
# 7   8       horse
# 8   9        ship
# 9  10         cat
#
# Total images: 50000
#
# Unique classes: <StringArray>
# [      'frog',      'truck',       'deer', 'automobile',       'bird',
#       'horse',       'ship',        'cat',        'dog',   'airplane']
# Length: 10, dtype: str

# %%
fig, axes = plt.subplots(2, 5, figsize=(12, 5))
axes = axes.flatten()

for i, ax in enumerate(axes):
    img_id = labels_df.iloc[i, 0]          # get the numeric id
    label = labels_df.iloc[i, 1]           # get the label
    
    img_path = f'cifar-10/train/train/{img_id}.png'
    img = Image.open(img_path)
    
    ax.imshow(img)
    ax.set_title(label)
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
import torch
from torch.utils.data import Dataset
from torchvision.transforms import v2 as transforms

class CIFARDataset(Dataset):
    # Dataset is a base class provided by PyTorch.
    # by inheriting from it, PyTorch knows how to work with our class
    # automatically — especially the DataLoader we'll create later.
    
    def __init__(self, labels_df, img_dir, augment=False):
        # __init__ is the constructor, called when you do CIFARDataset(...)
        # we're just storing the data we'll need later for lookups
        # augment=True for training data, False for validation data
        
        self.img_dir = img_dir
        
        # extract the image ids (first column) as a plain python list.
        # .values gives us a numpy array, .tolist() converts it to a list.
        self.img_ids = labels_df.iloc[:, 0].values.tolist()
        
        # extract the string labels (second column) the same way
        raw_labels = labels_df.iloc[:, 1].values.tolist()
        
        # the model needs integer labels, not strings like "dog" or "truck".
        # so we build a mapping from each unique label string to an integer.
        # sorted() ensures the mapping is consistent every time we run this.
        # example result: {"airplane":0, "automobile":1, "bird":2, ...}
        unique_labels = sorted(set(raw_labels))
        self.label_to_idx = {label: idx for idx, label in enumerate(unique_labels)}
        
        # now convert every raw string label to its integer equivalent.
        # this is a list comprehension — equivalent to a foreach loop that
        # builds a new list, like: [transform(x) for x in collection]
        self.labels = [self.label_to_idx[label] for label in raw_labels]
        
        if augment:
            # training transform — includes random augmentations.
            # each of these is applied randomly every time an image is loaded,
            # so the model sees a different version of each image each epoch.
            self.transform = transforms.Compose([
                
                transforms.ToImage(),
                transforms.ToDtype(torch.float32, scale=True),
                
                # randomly flip the image horizontally with 50% probability.
                # a dog facing left is still a dog — this teaches the model that.
                transforms.RandomHorizontalFlip(p=0.5),
                
                # randomly crop the image — first pad it by 4 pixels on each
                # side, then crop back to 32x32. this teaches the model that
                # the subject doesn't always need to be perfectly centered.
                transforms.RandomCrop(32, padding=4),
                
                # randomly adjust brightness, contrast, saturation, and hue
                # by small amounts. teaches the model to recognize objects
                # regardless of lighting conditions or color variations.
                transforms.ColorJitter(
                    brightness=0.1,
                    contrast=0.1,
                    saturation=0.1,
                    hue=0.05
                ),
                
                transforms.Normalize(
                    mean=[0.4914, 0.4822, 0.4465],
                    std=[0.2470, 0.2435, 0.2616]
                )
            ])
        else:
            # validation transform — no augmentation, just the bare minimum
            # processing needed to feed the image to the model.
            self.transform = transforms.Compose([
                transforms.ToImage(),
                transforms.ToDtype(torch.float32, scale=True),
                transforms.Normalize(
                    mean=[0.4914, 0.4822, 0.4465],
                    std=[0.2470, 0.2435, 0.2616]
                )
            ])
    
    def __len__(self):
        # PyTorch calls this to know how many items are in the dataset.
        # it's used by the DataLoader to know when one full pass is complete.
        return len(self.img_ids)
    
    def __getitem__(self, idx):
        # PyTorch calls this whenever it needs one specific item by index.
        # idx is just an integer — "give me item number 42"
        
        # build the full file path for this image
        img_path = os.path.join(self.img_dir, f"{self.img_ids[idx]}.png")
        
        # open the image as a PIL image (same as we did in the preview cell)
        image = Image.open(img_path)
        
        # apply our transform pipeline (ToTensor + Normalize)
        image = self.transform(image)
        
        # fetch the integer label for this image
        label = self.labels[idx]
        
        # return both as a tuple — PyTorch expects (data, label) pairs
        return image, label


# create an instance of our dataset, passing in the dataframe and image folder
dataset = CIFARDataset(labels_df, 'cifar-10/train/train')

print(f"Dataset size: {len(dataset)}")
print(f"Label mapping: {dataset.label_to_idx}")
# Out:
# Dataset size: 50000
# Label mapping: {'airplane': 0, 'automobile': 1, 'bird': 2, 'cat': 3, 'deer': 4, 'dog': 5, 'frog': 6, 'horse': 7, 'ship': 8, 'truck': 9}

# %%
# fetch one sample from the dataset — this calls __getitem__(0) internally
image_tensor, label_idx = dataset[0]

print(f"Tensor shape: {image_tensor.shape}")
# shape will be [3, 32, 32] meaning 3 color channels, 32x32 pixels.
# note that pytorch orders dimensions as [channels, height, width],
# which is the opposite of what PIL and matplotlib expect.

print(f"Tensor value range: {image_tensor.min():.2f} to {image_tensor.max():.2f}")
# should be roughly -1.0 to 1.0 after normalization

print(f"Label index: {label_idx}")

# to display the tensor as an image we need to reverse the normalization
# and swap the dimension order back to [height, width, channels] for matplotlib.
# permute(1, 2, 0) rearranges from [channels, height, width] -> [height, width, channels]
img_to_show = image_tensor.permute(1, 2, 0)

# reverse the normalization: undo the -1 to 1 scaling back to 0.0-1.0
# clamp makes sure no values accidentally sneak outside that range
img_to_show = (img_to_show * 0.5 + 0.5).clamp(0, 1)

plt.imshow(img_to_show)
plt.title(f"Label: {list(dataset.label_to_idx.keys())[label_idx]}")
plt.axis('off')
plt.show()
# Out:
# Tensor shape: torch.Size([3, 32, 32])
# Tensor value range: -1.99 to 2.09
# Label index: 6

# %%
from torch.utils.data import DataLoader

# load the pre-split CSVs instead of the original labels file
train_df = pd.read_csv('cifar-10/train_split.csv')
val_df = pd.read_csv('cifar-10/val_split.csv')

print(f"Training images: {len(train_df)}")
print(f"Validation images: {len(val_df)}")

# create separate datasets for training and validation.
# they point to the same image folder since the images aren't
# physically split — only the CSVs are different.
train_dataset = CIFARDataset(train_df, 'cifar-10/train/train', augment=True)
val_dataset = CIFARDataset(val_df, 'cifar-10/train/train', augment=False)

print(f"Label mapping: {train_dataset.label_to_idx}")

# training dataloader — shuffle is True so the model sees
# images in a different order each epoch
train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True,
    num_workers=2
)

# validation dataloader — shuffle is False since we're just
# measuring accuracy, order doesn't affect that.
# we can also use a larger batch size since we're not storing
# gradients during validation, which saves GPU memory.
val_loader = DataLoader(
    val_dataset,
    batch_size=64,
    shuffle=False,
    num_workers=2
)

print(f"Training batches per epoch: {len(train_loader)}")
print(f"Validation batches per epoch: {len(val_loader)}")
# Out:
# Training images: 40000
# Validation images: 10000
# Label mapping: {'airplane': 0, 'automobile': 1, 'bird': 2, 'cat': 3, 'deer': 4, 'dog': 5, 'frog': 6, 'horse': 7, 'ship': 8, 'truck': 9}
# Training batches per epoch: 1250
# Validation batches per epoch: 157

# %%
# grab one batch from the dataloader.
# next() fetches the first item from the iterator.
# iter() turns the dataloader into something we can call next() on.
images, labels = next(iter(train_loader))

print(f"Batch image tensor shape: {images.shape}")
# shape will be [32, 3, 32, 32] — batch_size, channels, height, width.
# this is the first time we've seen a 4-dimensional tensor —
# the batch dimension is just stacked on top of the per-image dimensions.

print(f"Batch label tensor shape: {labels.shape}")
# shape will be [32] — just a flat list of 32 integer labels

# display the first 8 images in the batch
fig, axes = plt.subplots(1, 8, figsize=(16, 2))

for i, ax in enumerate(axes):
    img = images[i]                         # grab one image tensor [3, 32, 32]
    img = img.permute(1, 2, 0)             # reorder to [32, 32, 3] for matplotlib
    img = (img * 0.5 + 0.5).clamp(0, 1)   # reverse normalization back to 0.0-1.0
    
    label_name = list(train_dataset.label_to_idx.keys())[labels[i]]
    
    ax.imshow(img)
    ax.set_title(label_name, fontsize=8)
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Batch image tensor shape: torch.Size([32, 3, 32, 32])
# Batch label tensor shape: torch.Size([32])

# %%
import torch.nn as nn

class CIFARClassifier(nn.Module):
    
    def __init__(self, dropout=0.25):
        super().__init__()
        
        # --- FEATURE EXTRACTION LAYERS ---
        # these layers learn to recognize visual patterns in the image.
        # think of them as progressively learning simple -> complex features.
        # early layers might detect edges, later layers detect shapes/objects.
        
        # first convolutional layer.
        # takes the 3 input channels (R, G, B) and produces 32 "filtered" versions
        # of the image, each one highlighting different patterns it has learned.
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1)
        
        # second convolutional layer.
        # takes the 32 filtered images from conv1 and produces 64.
        # we're doubling the depth while the spatial size will be shrinking (see pool below).
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        
        # third convolutional layer.
        # takes 64 and produces 128 — same pattern, more depth.
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1)
        
        # max pooling layer — we'll reuse this same layer multiple times in forward().
        # its job is to shrink the spatial size (height and width) of the image by half
        # after each convolutional layer, which reduces computation and helps the model
        # focus on the most prominent features rather than exact pixel positions.
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        
        # ReLU activation function — also reused multiple times.
        # after each convolution, this introduces non-linearity by simply setting
        # any negative values to zero. without this, stacking layers would be
        # mathematically equivalent to just having one layer.
        self.relu = nn.ReLU()
        
        # --- CLASSIFICATION LAYERS ---
        # after feature extraction, we flatten the 3D output into a 1D list of numbers
        # and pass it through standard "dense" layers to produce the final prediction.
        
        # flatten converts [batch, channels, height, width] -> [batch, channels*height*width].
        # after 3 rounds of conv+pool on a 32x32 image:
        #   32x32 -> 16x16 (after pool 1)
        #   16x16 -> 8x8   (after pool 2)
        #   8x8   -> 4x4   (after pool 3)
        # so the flattened size is 128 channels * 4 * 4 = 2048
        self.flatten = nn.Flatten()
        
        # first dense layer — takes the 2048 flattened values down to 512.
        self.fc1 = nn.Linear(2048, 512)
        
        # output layer — takes 512 values down to 10, one per class.
        # the highest value among these 10 will be the model's predicted class.
        self.fc2 = nn.Linear(512, 10)
        
        # dropout — randomly disables neurons during training.
        # this forces the model to not rely too heavily on any single neuron,
        # which helps prevent overfitting (memorizing training data rather than
        # learning general patterns). dropout is automatically disabled during
        # evaluation/inference, we don't need to worry about that manually.
        self.dropout = nn.Dropout(p=dropout)
    
    def forward(self, x):
        # x starts as [batch_size, 3, 32, 32]
        
        x = self.relu(self.conv1(x))  # -> [batch_size, 32, 32, 32]
        x = self.pool(x)              # -> [batch_size, 32, 16, 16]
        
        x = self.relu(self.conv2(x))  # -> [batch_size, 64, 16, 16]
        x = self.pool(x)              # -> [batch_size, 64, 8, 8]
        
        x = self.relu(self.conv3(x))  # -> [batch_size, 128, 8, 8]
        x = self.pool(x)              # -> [batch_size, 128, 4, 4]
        
        x = self.flatten(x)           # -> [batch_size, 2048]
        x = self.dropout(x)           # randomly zero out 25% of values
        
        x = self.relu(self.fc1(x))    # -> [batch_size, 512]
        x = self.dropout(x)           # dropout again before final layer
        
        x = self.fc2(x)               # -> [batch_size, 10]
        return x


## instantiate the model and move it to the GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# model = CIFARClassifier().to(device)

# # print a summary of the model's layers and parameter counts
# print(model)
# Out:
# Using device: cuda

# %%
import torch.optim as optim

NUM_EPOCHS = 60

# Best hyperparameters from Optuna search
lr = 0.0066244400307505225
dropout = 0.17851878421865774

# instantiate the model with the tuned dropout value
model = CIFARClassifier(dropout=dropout).to(device)

# CrossEntropyLoss measures how wrong the model's predictions are.
# it expects raw scores from the model (not probabilities) and the
# correct class index as an integer — which is exactly what we're providing.
criterion = nn.CrossEntropyLoss()

# SGD with momentum — momentum is important for SGD and should
# always be set to 0.9 as a standard practice
optimizer = optim.SGD(
    model.parameters(),
    lr=lr,
    momentum=0.9,
    weight_decay=1e-4
)

# CosineAnnealingLR smoothly reduces the learning rate following a
# cosine curve over the entire training run, rather than making
# sudden sharp drops every 10 epochs. this tends to produce better
# final results as the learning rate decays more gracefully.
# T_max is the number of epochs over which to complete the annealing.
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS)

print(f"Training for {NUM_EPOCHS} epochs")
print(f"Loss function: {criterion}")
print(f"Optimizer: {optimizer}")
print(f"Model parameters: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# Training for 60 epochs
# Loss function: CrossEntropyLoss()
# Optimizer: SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     initial_lr: 0.0066244400307505225
#     lr: 0.0066244400307505225
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0.0001
# )
# Model parameters: 1,147,466

# %%
# put the model in training mode. this enables behaviors that should
# only happen during training, like dropout randomly disabling neurons.
# the model has two modes: model.train() and model.eval().
model.train()

# history lists — we'll use these after training to plot loss and accuracy curves.
history = {
    'train_loss': [],
    'val_loss': [],
    'train_acc': [],
    'val_acc': [],
}

for epoch in range(NUM_EPOCHS):
    # --- TRAINING PHASE ---
    model.train()
    
    # track the total loss across all batches in this epoch
    running_loss = 0.0
    # track how many predictions were correct
    correct = 0
    # track how many images we've processed total
    total = 0
    
    for batch_idx, (images, labels) in enumerate(train_loader):
        
        # move the images and labels to the GPU.
        # they come off the dataloader as CPU tensors, so we need to
        # explicitly move them to the same device as the model.
        images = images.to(device)
        labels = labels.to(device)
        
        # zero out the gradients from the previous batch.
        # gradients accumulate by default in PyTorch — if we don't
        # clear them, they'd stack up across batches and corrupt the updates.
        optimizer.zero_grad()
        
        # forward pass — feed the images through the model.
        # this calls our forward() method and returns raw scores for each class.
        # shape: [batch_size, 10] — one score per class per image.
        outputs = model(images)
        
        # calculate the loss — how wrong were our predictions?
        # criterion compares our raw scores against the correct labels.
        loss = criterion(outputs, labels)
        
        # backward pass — calculate how much each weight contributed to the loss.
        # this is backpropagation. PyTorch handles all the math automatically.
        loss.backward()
        
        # update the weights based on the gradients calculated above.
        # this is the actual "learning" step.
        optimizer.step()
        
        # accumulate the loss for reporting.
        # .item() converts a single-value tensor to a plain python float.
        running_loss += loss.item()
        
        # calculate accuracy for this batch.
        # outputs contains raw scores — the highest score is the prediction.
        # torch.max returns both the highest value and its index.
        # we only want the index (which class), so we use _ for the value.
        _, predicted = torch.max(outputs, dim=1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
        # print progress every 200 batches so we can see it's working
        if (batch_idx + 1) % 200 == 0:
            print(
                f"Epoch [{epoch+1}/{NUM_EPOCHS}] "
                f"Batch [{batch_idx+1}/{len(train_loader)}] "
                f"Loss: {running_loss / (batch_idx + 1):.4f} "
                f"Accuracy: {100 * correct / total:.2f}%"
            )
            
    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    
    # --- VALIDATION PHASE ---
    # torch.no_grad() tells PyTorch not to calculate or store gradients
    # during this phase. we're not learning here, just measuring, so
    # there's no need — and skipping it saves significant GPU memory.
    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)
            
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            val_loss += loss.item()
            _, predicted = torch.max(outputs, dim=1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()
    
    val_loss = val_loss / len(val_loader)
    val_acc = 100 * val_correct / val_total
    
    # record metrics for plotting
    history['train_loss'].append(train_loss)
    history['val_loss'].append(val_loss)
    history['train_acc'].append(train_acc)
    history['val_acc'].append(val_acc)
    
    # step the scheduler at the end of each epoch.
    # this is what actually reduces the learning rate every 10 epochs.
    scheduler.step()
    
    # print both training and validation results for this epoch.
    # the gap between train_acc and val_acc is your overfitting indicator —
    # a large gap means the model is memorizing rather than generalizing.
    print(
        f"\n--- Epoch [{epoch+1}/{NUM_EPOCHS}] Complete | "
        f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | "
        f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.2f}% ---\n"
    )
# Out:
# Epoch [1/60] Batch [200/1250] Loss: 2.1608 Accuracy: 19.67%
# Epoch [1/60] Batch [400/1250] Loss: 2.0387 Accuracy: 24.20%
# Epoch [1/60] Batch [600/1250] Loss: 1.9428 Accuracy: 28.07%
# Epoch [1/60] Batch [800/1250] Loss: 1.8655 Accuracy: 30.93%
# Epoch [1/60] Batch [1000/1250] Loss: 1.8099 Accuracy: 33.08%
# Epoch [1/60] Batch [1200/1250] Loss: 1.7611 Accuracy: 35.07%
#
# --- Epoch [1/60] Complete | Train Loss: 1.7513 | Train Acc: 35.38% | Val Loss: 1.3497 | Val Acc: 51.42% ---
#
# Epoch [2/60] Batch [200/1250] Loss: 1.4415 Accuracy: 46.98%
# Epoch [2/60] Batch [400/1250] Loss: 1.4245 Accuracy: 47.64%
# Epoch [2/60] Batch [600/1250] Loss: 1.4059 Accuracy: 48.51%
# Epoch [2/60] Batch [800/1250] Loss: 1.3906 Accuracy: 49.31%
# Epoch [2/60] Batch [1000/1250] Loss: 1.3690 Accuracy: 50.27%
# Epoch [2/60] Batch [1200/1250] Loss: 1.3490 Accuracy: 51.06%
#
# --- Epoch [2/60] Complete | Train Loss: 1.3444 | Train Acc: 51.30% | Val Loss: 1.1102 | Val Acc: 61.64% ---
#
# Epoch [3/60] Batch [200/1250] Loss: 1.1922 Accuracy: 58.02%
# Epoch [3/60] Batch [400/1250] Loss: 1.1993 Accuracy: 57.62%
# Epoch [3/60] Batch [600/1250] Loss: 1.1840 Accuracy: 58.08%
# Epoch [3/60] Batch [800/1250] Loss: 1.1661 Accuracy: 58.69%
# Epoch [3/60] Batch [1000/1250] Loss: 1.1529 Accuracy: 59.09%
# Epoch [3/60] Batch [1200/1250] Loss: 1.1384 Accuracy: 59.60%
#
# --- Epoch [3/60] Complete | Train Loss: 1.1348 | Train Acc: 59.70% | Val Loss: 0.9362 | Val Acc: 67.68% ---
#
# Epoch [4/60] Batch [200/1250] Loss: 1.0597 Accuracy: 62.42%
# Epoch [4/60] Batch [400/1250] Loss: 1.0488 Accuracy: 62.70%
# Epoch [4/60] Batch [600/1250] Loss: 1.0431 Accuracy: 63.07%
# Epoch [4/60] Batch [800/1250] Loss: 1.0347 Accuracy: 63.46%
# Epoch [4/60] Batch [1000/1250] Loss: 1.0215 Accuracy: 63.79%
# Epoch [4/60] Batch [1200/1250] Loss: 1.0153 Accuracy: 64.10%
#
# --- Epoch [4/60] Complete | Train Loss: 1.0126 | Train Acc: 64.22% | Val Loss: 0.8506 | Val Acc: 70.22% ---
#
# Epoch [5/60] Batch [200/1250] Loss: 0.9564 Accuracy: 66.09%
# Epoch [5/60] Batch [400/1250] Loss: 0.9421 Accuracy: 66.77%
# Epoch [5/60] Batch [600/1250] Loss: 0.9407 Accuracy: 66.78%
# Epoch [5/60] Batch [800/1250] Loss: 0.9385 Accuracy: 67.06%
# Epoch [5/60] Batch [1000/1250] Loss: 0.9308 Accuracy: 67.40%
# Epoch [5/60] Batch [1200/1250] Loss: 0.9257 Accuracy: 67.63%
#
# --- Epoch [5/60] Complete | Train Loss: 0.9280 | Train Acc: 67.51% | Val Loss: 0.8394 | Val Acc: 71.03% ---
#
# Epoch [6/60] Batch [200/1250] Loss: 0.8888 Accuracy: 68.81%
# Epoch [6/60] Batch [400/1250] Loss: 0.8825 Accuracy: 69.12%
# Epoch [6/60] Batch [600/1250] Loss: 0.8760 Accuracy: 69.29%
# Epoch [6/60] Batch [800/1250] Loss: 0.8718 Accuracy: 69.59%
# Epoch [6/60] Batch [1000/1250] Loss: 0.8722 Accuracy: 69.65%
# Epoch [6/60] Batch [1200/1250] Loss: 0.8708 Accuracy: 69.72%
#
# --- Epoch [6/60] Complete | Train Loss: 0.8705 | Train Acc: 69.72% | Val Loss: 0.7534 | Val Acc: 73.73% ---
#
# Epoch [7/60] Batch [200/1250] Loss: 0.8345 Accuracy: 70.38%
# Epoch [7/60] Batch [400/1250] Loss: 0.8268 Accuracy: 70.98%
# Epoch [7/60] Batch [600/1250] Loss: 0.8270 Accuracy: 71.04%
# Epoch [7/60] Batch [800/1250] Loss: 0.8274 Accuracy: 70.95%
# Epoch [7/60] Batch [1000/1250] Loss: 0.8282 Accuracy: 70.98%
# Epoch [7/60] Batch [1200/1250] Loss: 0.8286 Accuracy: 71.05%
#
# --- Epoch [7/60] Complete | Train Loss: 0.8291 | Train Acc: 71.04% | Val Loss: 0.7259 | Val Acc: 74.72% ---
#
# Epoch [8/60] Batch [200/1250] Loss: 0.7811 Accuracy: 73.02%
# Epoch [8/60] Batch [400/1250] Loss: 0.7925 Accuracy: 72.76%
# Epoch [8/60] Batch [600/1250] Loss: 0.7890 Accuracy: 72.86%
# Epoch [8/60] Batch [800/1250] Loss: 0.7855 Accuracy: 72.90%
# Epoch [8/60] Batch [1000/1250] Loss: 0.7867 Accuracy: 72.80%
# Epoch [8/60] Batch [1200/1250] Loss: 0.7860 Accuracy: 72.71%
#
# --- Epoch [8/60] Complete | Train Loss: 0.7863 | Train Acc: 72.70% | Val Loss: 0.7012 | Val Acc: 76.24% ---
#
# Epoch [9/60] Batch [200/1250] Loss: 0.7478 Accuracy: 74.05%
# Epoch [9/60] Batch [400/1250] Loss: 0.7583 Accuracy: 73.68%
# Epoch [9/60] Batch [600/1250] Loss: 0.7619 Accuracy: 73.44%
# Epoch [9/60] Batch [800/1250] Loss: 0.7575 Accuracy: 73.48%
# Epoch [9/60] Batch [1000/1250] Loss: 0.7542 Accuracy: 73.60%
# Epoch [9/60] Batch [1200/1250] Loss: 0.7576 Accuracy: 73.54%
#
# --- Epoch [9/60] Complete | Train Loss: 0.7585 | Train Acc: 73.51% | Val Loss: 0.6801 | Val Acc: 76.62% ---
#
# Epoch [10/60] Batch [200/1250] Loss: 0.7409 Accuracy: 74.02%
# Epoch [10/60] Batch [400/1250] Loss: 0.7358 Accuracy: 74.16%
# Epoch [10/60] Batch [600/1250] Loss: 0.7295 Accuracy: 74.41%
# Epoch [10/60] Batch [800/1250] Loss: 0.7327 Accuracy: 74.38%
# Epoch [10/60] Batch [1000/1250] Loss: 0.7320 Accuracy: 74.39%
# Epoch [10/60] Batch [1200/1250] Loss: 0.7304 Accuracy: 74.53%
#
# --- Epoch [10/60] Complete | Train Loss: 0.7300 | Train Acc: 74.53% | Val Loss: 0.6269 | Val Acc: 77.93% ---
#
# Epoch [11/60] Batch [200/1250] Loss: 0.7086 Accuracy: 75.58%
# Epoch [11/60] Batch [400/1250] Loss: 0.7115 Accuracy: 75.39%
# Epoch [11/60] Batch [600/1250] Loss: 0.7125 Accuracy: 75.28%
# Epoch [11/60] Batch [800/1250] Loss: 0.7092 Accuracy: 75.35%
# Epoch [11/60] Batch [1000/1250] Loss: 0.7114 Accuracy: 75.37%
# Epoch [11/60] Batch [1200/1250] Loss: 0.7104 Accuracy: 75.36%
#
# --- Epoch [11/60] Complete | Train Loss: 0.7103 | Train Acc: 75.34% | Val Loss: 0.6470 | Val Acc: 77.69% ---
#
# Epoch [12/60] Batch [200/1250] Loss: 0.6741 Accuracy: 76.88%
# Epoch [12/60] Batch [400/1250] Loss: 0.6707 Accuracy: 76.83%
# Epoch [12/60] Batch [600/1250] Loss: 0.6729 Accuracy: 76.52%
# Epoch [12/60] Batch [800/1250] Loss: 0.6694 Accuracy: 76.66%
# Epoch [12/60] Batch [1000/1250] Loss: 0.6747 Accuracy: 76.52%
# Epoch [12/60] Batch [1200/1250] Loss: 0.6795 Accuracy: 76.15%
#
# --- Epoch [12/60] Complete | Train Loss: 0.6812 | Train Acc: 76.06% | Val Loss: 0.6140 | Val Acc: 78.52% ---
#
# Epoch [13/60] Batch [200/1250] Loss: 0.6395 Accuracy: 77.48%
# Epoch [13/60] Batch [400/1250] Loss: 0.6551 Accuracy: 77.05%
# Epoch [13/60] Batch [600/1250] Loss: 0.6607 Accuracy: 77.08%
# Epoch [13/60] Batch [800/1250] Loss: 0.6643 Accuracy: 76.96%
# Epoch [13/60] Batch [1000/1250] Loss: 0.6630 Accuracy: 76.95%
# Epoch [13/60] Batch [1200/1250] Loss: 0.6674 Accuracy: 76.89%
#
# --- Epoch [13/60] Complete | Train Loss: 0.6679 | Train Acc: 76.85% | Val Loss: 0.5976 | Val Acc: 79.31% ---
#
# Epoch [14/60] Batch [200/1250] Loss: 0.6580 Accuracy: 76.91%
# Epoch [14/60] Batch [400/1250] Loss: 0.6412 Accuracy: 77.38%
# Epoch [14/60] Batch [600/1250] Loss: 0.6450 Accuracy: 77.38%
# Epoch [14/60] Batch [800/1250] Loss: 0.6448 Accuracy: 77.39%
# Epoch [14/60] Batch [1000/1250] Loss: 0.6471 Accuracy: 77.32%
# Epoch [14/60] Batch [1200/1250] Loss: 0.6466 Accuracy: 77.35%
#
# --- Epoch [14/60] Complete | Train Loss: 0.6463 | Train Acc: 77.38% | Val Loss: 0.6032 | Val Acc: 79.14% ---
#
# Epoch [15/60] Batch [200/1250] Loss: 0.6070 Accuracy: 79.16%
# Epoch [15/60] Batch [400/1250] Loss: 0.6226 Accuracy: 78.35%
# Epoch [15/60] Batch [600/1250] Loss: 0.6207 Accuracy: 78.39%
# Epoch [15/60] Batch [800/1250] Loss: 0.6181 Accuracy: 78.50%
# Epoch [15/60] Batch [1000/1250] Loss: 0.6215 Accuracy: 78.39%
# Epoch [15/60] Batch [1200/1250] Loss: 0.6262 Accuracy: 78.22%
#
# --- Epoch [15/60] Complete | Train Loss: 0.6263 | Train Acc: 78.22% | Val Loss: 0.6165 | Val Acc: 78.98% ---
#
# Epoch [16/60] Batch [200/1250] Loss: 0.5871 Accuracy: 79.55%
# Epoch [16/60] Batch [400/1250] Loss: 0.6117 Accuracy: 78.72%
# Epoch [16/60] Batch [600/1250] Loss: 0.6099 Accuracy: 78.99%
# Epoch [16/60] Batch [800/1250] Loss: 0.6054 Accuracy: 79.06%
# Epoch [16/60] Batch [1000/1250] Loss: 0.6042 Accuracy: 79.03%
# Epoch [16/60] Batch [1200/1250] Loss: 0.6069 Accuracy: 78.95%
#
# --- Epoch [16/60] Complete | Train Loss: 0.6086 | Train Acc: 78.88% | Val Loss: 0.5742 | Val Acc: 80.30% ---
#
# Epoch [17/60] Batch [200/1250] Loss: 0.5986 Accuracy: 78.95%
# Epoch [17/60] Batch [400/1250] Loss: 0.5996 Accuracy: 78.70%
# Epoch [17/60] Batch [600/1250] Loss: 0.5989 Accuracy: 78.74%
# Epoch [17/60] Batch [800/1250] Loss: 0.5983 Accuracy: 78.89%
# Epoch [17/60] Batch [1000/1250] Loss: 0.6014 Accuracy: 78.77%
# Epoch [17/60] Batch [1200/1250] Loss: 0.6022 Accuracy: 78.85%
#
# --- Epoch [17/60] Complete | Train Loss: 0.6025 | Train Acc: 78.81% | Val Loss: 0.5581 | Val Acc: 80.85% ---
#
# Epoch [18/60] Batch [200/1250] Loss: 0.6073 Accuracy: 78.73%
# Epoch [18/60] Batch [400/1250] Loss: 0.5898 Accuracy: 79.30%
# Epoch [18/60] Batch [600/1250] Loss: 0.5878 Accuracy: 79.40%
# Epoch [18/60] Batch [800/1250] Loss: 0.5822 Accuracy: 79.64%
# Epoch [18/60] Batch [1000/1250] Loss: 0.5834 Accuracy: 79.57%
# Epoch [18/60] Batch [1200/1250] Loss: 0.5869 Accuracy: 79.42%
#
# --- Epoch [18/60] Complete | Train Loss: 0.5870 | Train Acc: 79.41% | Val Loss: 0.5377 | Val Acc: 81.80% ---
#
# Epoch [19/60] Batch [200/1250] Loss: 0.5801 Accuracy: 79.84%
# Epoch [19/60] Batch [400/1250] Loss: 0.5704 Accuracy: 80.14%
# Epoch [19/60] Batch [600/1250] Loss: 0.5774 Accuracy: 79.93%
# Epoch [19/60] Batch [800/1250] Loss: 0.5746 Accuracy: 80.04%
# Epoch [19/60] Batch [1000/1250] Loss: 0.5713 Accuracy: 80.12%
# Epoch [19/60] Batch [1200/1250] Loss: 0.5682 Accuracy: 80.27%
#
# --- Epoch [19/60] Complete | Train Loss: 0.5692 | Train Acc: 80.20% | Val Loss: 0.5533 | Val Acc: 80.82% ---
#
# Epoch [20/60] Batch [200/1250] Loss: 0.5729 Accuracy: 79.88%
# Epoch [20/60] Batch [400/1250] Loss: 0.5590 Accuracy: 80.50%
# Epoch [20/60] Batch [600/1250] Loss: 0.5519 Accuracy: 80.71%
# Epoch [20/60] Batch [800/1250] Loss: 0.5511 Accuracy: 80.72%
# Epoch [20/60] Batch [1000/1250] Loss: 0.5528 Accuracy: 80.63%
# Epoch [20/60] Batch [1200/1250] Loss: 0.5535 Accuracy: 80.63%
#
# --- Epoch [20/60] Complete | Train Loss: 0.5532 | Train Acc: 80.61% | Val Loss: 0.5476 | Val Acc: 81.30% ---
#
# Epoch [21/60] Batch [200/1250] Loss: 0.5514 Accuracy: 80.55%
# Epoch [21/60] Batch [400/1250] Loss: 0.5382 Accuracy: 81.24%
# Epoch [21/60] Batch [600/1250] Loss: 0.5417 Accuracy: 81.04%
# Epoch [21/60] Batch [800/1250] Loss: 0.5461 Accuracy: 80.91%
# Epoch [21/60] Batch [1000/1250] Loss: 0.5458 Accuracy: 80.92%
# Epoch [21/60] Batch [1200/1250] Loss: 0.5432 Accuracy: 80.99%
#
# --- Epoch [21/60] Complete | Train Loss: 0.5442 | Train Acc: 80.96% | Val Loss: 0.5127 | Val Acc: 82.13% ---
#
# Epoch [22/60] Batch [200/1250] Loss: 0.5249 Accuracy: 82.09%
# Epoch [22/60] Batch [400/1250] Loss: 0.5263 Accuracy: 82.06%
# Epoch [22/60] Batch [600/1250] Loss: 0.5316 Accuracy: 81.83%
# Epoch [22/60] Batch [800/1250] Loss: 0.5261 Accuracy: 81.83%
# Epoch [22/60] Batch [1000/1250] Loss: 0.5243 Accuracy: 81.89%
# Epoch [22/60] Batch [1200/1250] Loss: 0.5297 Accuracy: 81.60%
#
# --- Epoch [22/60] Complete | Train Loss: 0.5299 | Train Acc: 81.58% | Val Loss: 0.5040 | Val Acc: 82.63% ---
#
# Epoch [23/60] Batch [200/1250] Loss: 0.4955 Accuracy: 82.64%
# Epoch [23/60] Batch [400/1250] Loss: 0.5031 Accuracy: 82.25%
# Epoch [23/60] Batch [600/1250] Loss: 0.5089 Accuracy: 82.23%
# Epoch [23/60] Batch [800/1250] Loss: 0.5118 Accuracy: 82.16%
# Epoch [23/60] Batch [1000/1250] Loss: 0.5141 Accuracy: 81.98%
# Epoch [23/60] Batch [1200/1250] Loss: 0.5155 Accuracy: 82.00%
#
# --- Epoch [23/60] Complete | Train Loss: 0.5147 | Train Acc: 82.03% | Val Loss: 0.5192 | Val Acc: 81.93% ---
#
# Epoch [24/60] Batch [200/1250] Loss: 0.5020 Accuracy: 82.70%
# Epoch [24/60] Batch [400/1250] Loss: 0.5011 Accuracy: 82.54%
# Epoch [24/60] Batch [600/1250] Loss: 0.4993 Accuracy: 82.67%
# Epoch [24/60] Batch [800/1250] Loss: 0.5040 Accuracy: 82.51%
# Epoch [24/60] Batch [1000/1250] Loss: 0.5054 Accuracy: 82.42%
# Epoch [24/60] Batch [1200/1250] Loss: 0.5102 Accuracy: 82.34%
#
# --- Epoch [24/60] Complete | Train Loss: 0.5096 | Train Acc: 82.36% | Val Loss: 0.5013 | Val Acc: 82.72% ---
#
# Epoch [25/60] Batch [200/1250] Loss: 0.4652 Accuracy: 83.92%
# Epoch [25/60] Batch [400/1250] Loss: 0.4877 Accuracy: 83.21%
# Epoch [25/60] Batch [600/1250] Loss: 0.4926 Accuracy: 82.86%
# Epoch [25/60] Batch [800/1250] Loss: 0.4918 Accuracy: 82.84%
# Epoch [25/60] Batch [1000/1250] Loss: 0.4918 Accuracy: 82.80%
# Epoch [25/60] Batch [1200/1250] Loss: 0.4933 Accuracy: 82.74%
#
# --- Epoch [25/60] Complete | Train Loss: 0.4950 | Train Acc: 82.65% | Val Loss: 0.4978 | Val Acc: 83.14% ---
#
# Epoch [26/60] Batch [200/1250] Loss: 0.4886 Accuracy: 82.80%
# Epoch [26/60] Batch [400/1250] Loss: 0.4846 Accuracy: 82.74%
# Epoch [26/60] Batch [600/1250] Loss: 0.4794 Accuracy: 83.02%
# Epoch [26/60] Batch [800/1250] Loss: 0.4811 Accuracy: 83.02%
# Epoch [26/60] Batch [1000/1250] Loss: 0.4870 Accuracy: 82.91%
# Epoch [26/60] Batch [1200/1250] Loss: 0.4882 Accuracy: 82.90%
#
# --- Epoch [26/60] Complete | Train Loss: 0.4877 | Train Acc: 82.90% | Val Loss: 0.5010 | Val Acc: 83.11% ---
#
# Epoch [27/60] Batch [200/1250] Loss: 0.4853 Accuracy: 82.97%
# Epoch [27/60] Batch [400/1250] Loss: 0.4815 Accuracy: 83.09%
# Epoch [27/60] Batch [600/1250] Loss: 0.4760 Accuracy: 83.26%
# Epoch [27/60] Batch [800/1250] Loss: 0.4708 Accuracy: 83.47%
# Epoch [27/60] Batch [1000/1250] Loss: 0.4741 Accuracy: 83.32%
# Epoch [27/60] Batch [1200/1250] Loss: 0.4727 Accuracy: 83.45%
#
# --- Epoch [27/60] Complete | Train Loss: 0.4732 | Train Acc: 83.44% | Val Loss: 0.4834 | Val Acc: 83.70% ---
#
# Epoch [28/60] Batch [200/1250] Loss: 0.4661 Accuracy: 83.64%
# Epoch [28/60] Batch [400/1250] Loss: 0.4653 Accuracy: 83.56%
# Epoch [28/60] Batch [600/1250] Loss: 0.4653 Accuracy: 83.71%
# Epoch [28/60] Batch [800/1250] Loss: 0.4604 Accuracy: 83.86%
# Epoch [28/60] Batch [1000/1250] Loss: 0.4599 Accuracy: 83.89%
# Epoch [28/60] Batch [1200/1250] Loss: 0.4609 Accuracy: 83.77%
#
# --- Epoch [28/60] Complete | Train Loss: 0.4620 | Train Acc: 83.79% | Val Loss: 0.5008 | Val Acc: 82.89% ---
#
# Epoch [29/60] Batch [200/1250] Loss: 0.4305 Accuracy: 84.94%
# Epoch [29/60] Batch [400/1250] Loss: 0.4408 Accuracy: 84.21%
# Epoch [29/60] Batch [600/1250] Loss: 0.4485 Accuracy: 83.92%
# Epoch [29/60] Batch [800/1250] Loss: 0.4434 Accuracy: 84.19%
# Epoch [29/60] Batch [1000/1250] Loss: 0.4472 Accuracy: 84.11%
# Epoch [29/60] Batch [1200/1250] Loss: 0.4473 Accuracy: 84.16%
#
# --- Epoch [29/60] Complete | Train Loss: 0.4476 | Train Acc: 84.17% | Val Loss: 0.4932 | Val Acc: 83.33% ---
#
# Epoch [30/60] Batch [200/1250] Loss: 0.4226 Accuracy: 85.02%
# Epoch [30/60] Batch [400/1250] Loss: 0.4296 Accuracy: 84.83%
# Epoch [30/60] Batch [600/1250] Loss: 0.4283 Accuracy: 84.95%
# Epoch [30/60] Batch [800/1250] Loss: 0.4320 Accuracy: 84.88%
# Epoch [30/60] Batch [1000/1250] Loss: 0.4338 Accuracy: 84.85%
# Epoch [30/60] Batch [1200/1250] Loss: 0.4347 Accuracy: 84.82%
#
# --- Epoch [30/60] Complete | Train Loss: 0.4349 | Train Acc: 84.78% | Val Loss: 0.4793 | Val Acc: 83.62% ---
#
# Epoch [31/60] Batch [200/1250] Loss: 0.4229 Accuracy: 85.50%
# Epoch [31/60] Batch [400/1250] Loss: 0.4282 Accuracy: 85.10%
# Epoch [31/60] Batch [600/1250] Loss: 0.4213 Accuracy: 85.21%
# Epoch [31/60] Batch [800/1250] Loss: 0.4188 Accuracy: 85.20%
# Epoch [31/60] Batch [1000/1250] Loss: 0.4193 Accuracy: 85.23%
# Epoch [31/60] Batch [1200/1250] Loss: 0.4233 Accuracy: 85.10%
#
# --- Epoch [31/60] Complete | Train Loss: 0.4241 | Train Acc: 85.05% | Val Loss: 0.4664 | Val Acc: 84.27% ---
#
# Epoch [32/60] Batch [200/1250] Loss: 0.4201 Accuracy: 85.34%
# Epoch [32/60] Batch [400/1250] Loss: 0.4236 Accuracy: 85.17%
# Epoch [32/60] Batch [600/1250] Loss: 0.4289 Accuracy: 84.86%
# Epoch [32/60] Batch [800/1250] Loss: 0.4236 Accuracy: 84.98%
# Epoch [32/60] Batch [1000/1250] Loss: 0.4192 Accuracy: 85.09%
# Epoch [32/60] Batch [1200/1250] Loss: 0.4204 Accuracy: 85.05%
#
# --- Epoch [32/60] Complete | Train Loss: 0.4214 | Train Acc: 85.00% | Val Loss: 0.4653 | Val Acc: 84.01% ---
#
# Epoch [33/60] Batch [200/1250] Loss: 0.4178 Accuracy: 85.14%
# Epoch [33/60] Batch [400/1250] Loss: 0.4129 Accuracy: 85.43%
# Epoch [33/60] Batch [600/1250] Loss: 0.4144 Accuracy: 85.44%
# Epoch [33/60] Batch [800/1250] Loss: 0.4176 Accuracy: 85.35%
# Epoch [33/60] Batch [1000/1250] Loss: 0.4160 Accuracy: 85.42%
# Epoch [33/60] Batch [1200/1250] Loss: 0.4131 Accuracy: 85.54%
#
# --- Epoch [33/60] Complete | Train Loss: 0.4121 | Train Acc: 85.59% | Val Loss: 0.4724 | Val Acc: 83.81% ---
#
# Epoch [34/60] Batch [200/1250] Loss: 0.3941 Accuracy: 85.83%
# Epoch [34/60] Batch [400/1250] Loss: 0.4018 Accuracy: 85.76%
# Epoch [34/60] Batch [600/1250] Loss: 0.4022 Accuracy: 85.82%
# Epoch [34/60] Batch [800/1250] Loss: 0.4008 Accuracy: 85.81%
# Epoch [34/60] Batch [1000/1250] Loss: 0.3995 Accuracy: 85.95%
# Epoch [34/60] Batch [1200/1250] Loss: 0.3974 Accuracy: 86.06%
#
# --- Epoch [34/60] Complete | Train Loss: 0.3991 | Train Acc: 85.96% | Val Loss: 0.4490 | Val Acc: 84.70% ---
#
# Epoch [35/60] Batch [200/1250] Loss: 0.3702 Accuracy: 86.86%
# Epoch [35/60] Batch [400/1250] Loss: 0.3785 Accuracy: 86.72%
# Epoch [35/60] Batch [600/1250] Loss: 0.3816 Accuracy: 86.72%
# Epoch [35/60] Batch [800/1250] Loss: 0.3883 Accuracy: 86.53%
# Epoch [35/60] Batch [1000/1250] Loss: 0.3903 Accuracy: 86.52%
# Epoch [35/60] Batch [1200/1250] Loss: 0.3921 Accuracy: 86.40%
#
# --- Epoch [35/60] Complete | Train Loss: 0.3925 | Train Acc: 86.40% | Val Loss: 0.4591 | Val Acc: 84.39% ---
#
# Epoch [36/60] Batch [200/1250] Loss: 0.3757 Accuracy: 87.00%
# Epoch [36/60] Batch [400/1250] Loss: 0.3746 Accuracy: 86.90%
# Epoch [36/60] Batch [600/1250] Loss: 0.3733 Accuracy: 86.92%
# Epoch [36/60] Batch [800/1250] Loss: 0.3792 Accuracy: 86.68%
# Epoch [36/60] Batch [1000/1250] Loss: 0.3787 Accuracy: 86.79%
# Epoch [36/60] Batch [1200/1250] Loss: 0.3819 Accuracy: 86.70%
#
# --- Epoch [36/60] Complete | Train Loss: 0.3819 | Train Acc: 86.70% | Val Loss: 0.4479 | Val Acc: 84.64% ---
#
# Epoch [37/60] Batch [200/1250] Loss: 0.3475 Accuracy: 87.62%
# Epoch [37/60] Batch [400/1250] Loss: 0.3594 Accuracy: 87.16%
# Epoch [37/60] Batch [600/1250] Loss: 0.3575 Accuracy: 87.23%
# Epoch [37/60] Batch [800/1250] Loss: 0.3623 Accuracy: 87.05%
# Epoch [37/60] Batch [1000/1250] Loss: 0.3646 Accuracy: 87.01%
# Epoch [37/60] Batch [1200/1250] Loss: 0.3651 Accuracy: 86.96%
#
# --- Epoch [37/60] Complete | Train Loss: 0.3653 | Train Acc: 86.96% | Val Loss: 0.4333 | Val Acc: 85.23% ---
#
# Epoch [38/60] Batch [200/1250] Loss: 0.3462 Accuracy: 87.59%
# Epoch [38/60] Batch [400/1250] Loss: 0.3504 Accuracy: 87.53%
# Epoch [38/60] Batch [600/1250] Loss: 0.3540 Accuracy: 87.35%
# Epoch [38/60] Batch [800/1250] Loss: 0.3596 Accuracy: 87.22%
# Epoch [38/60] Batch [1000/1250] Loss: 0.3599 Accuracy: 87.29%
# Epoch [38/60] Batch [1200/1250] Loss: 0.3595 Accuracy: 87.39%
#
# --- Epoch [38/60] Complete | Train Loss: 0.3597 | Train Acc: 87.38% | Val Loss: 0.4572 | Val Acc: 84.58% ---
#
# Epoch [39/60] Batch [200/1250] Loss: 0.3376 Accuracy: 88.23%
# Epoch [39/60] Batch [400/1250] Loss: 0.3512 Accuracy: 87.92%
# Epoch [39/60] Batch [600/1250] Loss: 0.3499 Accuracy: 87.85%
# Epoch [39/60] Batch [800/1250] Loss: 0.3519 Accuracy: 87.71%
# Epoch [39/60] Batch [1000/1250] Loss: 0.3516 Accuracy: 87.72%
# Epoch [39/60] Batch [1200/1250] Loss: 0.3534 Accuracy: 87.62%
#
# --- Epoch [39/60] Complete | Train Loss: 0.3531 | Train Acc: 87.62% | Val Loss: 0.4308 | Val Acc: 85.32% ---
#
# Epoch [40/60] Batch [200/1250] Loss: 0.3324 Accuracy: 88.30%
# Epoch [40/60] Batch [400/1250] Loss: 0.3431 Accuracy: 87.85%
# Epoch [40/60] Batch [600/1250] Loss: 0.3436 Accuracy: 87.82%
# Epoch [40/60] Batch [800/1250] Loss: 0.3446 Accuracy: 87.84%
# Epoch [40/60] Batch [1000/1250] Loss: 0.3465 Accuracy: 87.71%
# Epoch [40/60] Batch [1200/1250] Loss: 0.3476 Accuracy: 87.71%
#
# --- Epoch [40/60] Complete | Train Loss: 0.3476 | Train Acc: 87.74% | Val Loss: 0.4346 | Val Acc: 85.19% ---
#
# Epoch [41/60] Batch [200/1250] Loss: 0.3213 Accuracy: 88.72%
# Epoch [41/60] Batch [400/1250] Loss: 0.3227 Accuracy: 88.66%
# Epoch [41/60] Batch [600/1250] Loss: 0.3293 Accuracy: 88.44%
# Epoch [41/60] Batch [800/1250] Loss: 0.3307 Accuracy: 88.35%
# Epoch [41/60] Batch [1000/1250] Loss: 0.3360 Accuracy: 88.12%
# Epoch [41/60] Batch [1200/1250] Loss: 0.3375 Accuracy: 88.07%
#
# --- Epoch [41/60] Complete | Train Loss: 0.3388 | Train Acc: 88.01% | Val Loss: 0.4446 | Val Acc: 84.91% ---
#
# Epoch [42/60] Batch [200/1250] Loss: 0.3125 Accuracy: 89.08%
# Epoch [42/60] Batch [400/1250] Loss: 0.3246 Accuracy: 88.41%
# Epoch [42/60] Batch [600/1250] Loss: 0.3295 Accuracy: 88.28%
# Epoch [42/60] Batch [800/1250] Loss: 0.3323 Accuracy: 88.28%
# Epoch [42/60] Batch [1000/1250] Loss: 0.3350 Accuracy: 88.13%
# Epoch [42/60] Batch [1200/1250] Loss: 0.3329 Accuracy: 88.20%
#
# --- Epoch [42/60] Complete | Train Loss: 0.3345 | Train Acc: 88.16% | Val Loss: 0.4307 | Val Acc: 85.35% ---
#
# Epoch [43/60] Batch [200/1250] Loss: 0.3129 Accuracy: 88.61%
# Epoch [43/60] Batch [400/1250] Loss: 0.3211 Accuracy: 88.48%
# Epoch [43/60] Batch [600/1250] Loss: 0.3200 Accuracy: 88.55%
# Epoch [43/60] Batch [800/1250] Loss: 0.3212 Accuracy: 88.54%
# Epoch [43/60] Batch [1000/1250] Loss: 0.3194 Accuracy: 88.61%
# Epoch [43/60] Batch [1200/1250] Loss: 0.3209 Accuracy: 88.55%
#
# --- Epoch [43/60] Complete | Train Loss: 0.3216 | Train Acc: 88.55% | Val Loss: 0.4267 | Val Acc: 85.52% ---
#
# Epoch [44/60] Batch [200/1250] Loss: 0.3341 Accuracy: 88.30%
# Epoch [44/60] Batch [400/1250] Loss: 0.3193 Accuracy: 88.62%
# Epoch [44/60] Batch [600/1250] Loss: 0.3170 Accuracy: 88.79%
# Epoch [44/60] Batch [800/1250] Loss: 0.3125 Accuracy: 88.89%
# Epoch [44/60] Batch [1000/1250] Loss: 0.3100 Accuracy: 88.97%
# Epoch [44/60] Batch [1200/1250] Loss: 0.3111 Accuracy: 88.99%
#
# --- Epoch [44/60] Complete | Train Loss: 0.3109 | Train Acc: 89.00% | Val Loss: 0.4400 | Val Acc: 85.41% ---
#
# Epoch [45/60] Batch [200/1250] Loss: 0.3224 Accuracy: 88.28%
# Epoch [45/60] Batch [400/1250] Loss: 0.3180 Accuracy: 88.52%
# Epoch [45/60] Batch [600/1250] Loss: 0.3167 Accuracy: 88.69%
# Epoch [45/60] Batch [800/1250] Loss: 0.3145 Accuracy: 88.82%
# Epoch [45/60] Batch [1000/1250] Loss: 0.3145 Accuracy: 88.87%
# Epoch [45/60] Batch [1200/1250] Loss: 0.3126 Accuracy: 88.90%
#
# --- Epoch [45/60] Complete | Train Loss: 0.3127 | Train Acc: 88.88% | Val Loss: 0.4274 | Val Acc: 85.56% ---
#
# Epoch [46/60] Batch [200/1250] Loss: 0.3007 Accuracy: 89.33%
# Epoch [46/60] Batch [400/1250] Loss: 0.3003 Accuracy: 89.10%
# Epoch [46/60] Batch [600/1250] Loss: 0.2991 Accuracy: 89.23%
# Epoch [46/60] Batch [800/1250] Loss: 0.3036 Accuracy: 89.22%
# Epoch [46/60] Batch [1000/1250] Loss: 0.3013 Accuracy: 89.32%
# Epoch [46/60] Batch [1200/1250] Loss: 0.3019 Accuracy: 89.30%
#
# --- Epoch [46/60] Complete | Train Loss: 0.3005 | Train Acc: 89.34% | Val Loss: 0.4223 | Val Acc: 85.69% ---
#
# Epoch [47/60] Batch [200/1250] Loss: 0.3093 Accuracy: 88.98%
# Epoch [47/60] Batch [400/1250] Loss: 0.2968 Accuracy: 89.36%
# Epoch [47/60] Batch [600/1250] Loss: 0.2927 Accuracy: 89.61%
# Epoch [47/60] Batch [800/1250] Loss: 0.2920 Accuracy: 89.64%
# Epoch [47/60] Batch [1000/1250] Loss: 0.2957 Accuracy: 89.53%
# Epoch [47/60] Batch [1200/1250] Loss: 0.2948 Accuracy: 89.58%
#
# --- Epoch [47/60] Complete | Train Loss: 0.2941 | Train Acc: 89.62% | Val Loss: 0.4249 | Val Acc: 85.81% ---
#
# Epoch [48/60] Batch [200/1250] Loss: 0.2714 Accuracy: 90.47%
# Epoch [48/60] Batch [400/1250] Loss: 0.2846 Accuracy: 89.85%
# Epoch [48/60] Batch [600/1250] Loss: 0.2866 Accuracy: 89.81%
# Epoch [48/60] Batch [800/1250] Loss: 0.2845 Accuracy: 89.96%
# Epoch [48/60] Batch [1000/1250] Loss: 0.2892 Accuracy: 89.77%
# Epoch [48/60] Batch [1200/1250] Loss: 0.2884 Accuracy: 89.73%
#
# --- Epoch [48/60] Complete | Train Loss: 0.2895 | Train Acc: 89.73% | Val Loss: 0.4281 | Val Acc: 85.49% ---
#
# Epoch [49/60] Batch [200/1250] Loss: 0.2825 Accuracy: 90.06%
# Epoch [49/60] Batch [400/1250] Loss: 0.2842 Accuracy: 89.91%
# Epoch [49/60] Batch [600/1250] Loss: 0.2822 Accuracy: 90.06%
# Epoch [49/60] Batch [800/1250] Loss: 0.2802 Accuracy: 90.11%
# Epoch [49/60] Batch [1000/1250] Loss: 0.2825 Accuracy: 89.99%
# Epoch [49/60] Batch [1200/1250] Loss: 0.2848 Accuracy: 89.90%
#
# --- Epoch [49/60] Complete | Train Loss: 0.2855 | Train Acc: 89.85% | Val Loss: 0.4209 | Val Acc: 86.06% ---
#
# Epoch [50/60] Batch [200/1250] Loss: 0.2830 Accuracy: 89.73%
# Epoch [50/60] Batch [400/1250] Loss: 0.2893 Accuracy: 89.83%
# Epoch [50/60] Batch [600/1250] Loss: 0.2868 Accuracy: 90.12%
# Epoch [50/60] Batch [800/1250] Loss: 0.2881 Accuracy: 90.05%
# Epoch [50/60] Batch [1000/1250] Loss: 0.2845 Accuracy: 90.07%
# Epoch [50/60] Batch [1200/1250] Loss: 0.2837 Accuracy: 90.14%
#
# --- Epoch [50/60] Complete | Train Loss: 0.2837 | Train Acc: 90.14% | Val Loss: 0.4185 | Val Acc: 86.11% ---
#
# Epoch [51/60] Batch [200/1250] Loss: 0.2639 Accuracy: 90.50%
# Epoch [51/60] Batch [400/1250] Loss: 0.2738 Accuracy: 90.30%
# Epoch [51/60] Batch [600/1250] Loss: 0.2761 Accuracy: 90.09%
# Epoch [51/60] Batch [800/1250] Loss: 0.2765 Accuracy: 90.12%
# Epoch [51/60] Batch [1000/1250] Loss: 0.2779 Accuracy: 90.03%
# Epoch [51/60] Batch [1200/1250] Loss: 0.2795 Accuracy: 89.92%
#
# --- Epoch [51/60] Complete | Train Loss: 0.2795 | Train Acc: 89.92% | Val Loss: 0.4190 | Val Acc: 86.07% ---
#
# Epoch [52/60] Batch [200/1250] Loss: 0.2809 Accuracy: 89.92%
# Epoch [52/60] Batch [400/1250] Loss: 0.2794 Accuracy: 90.26%
# Epoch [52/60] Batch [600/1250] Loss: 0.2820 Accuracy: 90.08%
# Epoch [52/60] Batch [800/1250] Loss: 0.2819 Accuracy: 90.06%
# Epoch [52/60] Batch [1000/1250] Loss: 0.2807 Accuracy: 90.10%
# Epoch [52/60] Batch [1200/1250] Loss: 0.2803 Accuracy: 90.08%
#
# --- Epoch [52/60] Complete | Train Loss: 0.2800 | Train Acc: 90.11% | Val Loss: 0.4168 | Val Acc: 86.13% ---
#
# Epoch [53/60] Batch [200/1250] Loss: 0.2661 Accuracy: 90.95%
# Epoch [53/60] Batch [400/1250] Loss: 0.2683 Accuracy: 90.95%
# Epoch [53/60] Batch [600/1250] Loss: 0.2717 Accuracy: 90.67%
# Epoch [53/60] Batch [800/1250] Loss: 0.2685 Accuracy: 90.74%
# Epoch [53/60] Batch [1000/1250] Loss: 0.2686 Accuracy: 90.65%
# Epoch [53/60] Batch [1200/1250] Loss: 0.2683 Accuracy: 90.65%
#
# --- Epoch [53/60] Complete | Train Loss: 0.2677 | Train Acc: 90.69% | Val Loss: 0.4181 | Val Acc: 86.15% ---
#
# Epoch [54/60] Batch [200/1250] Loss: 0.2852 Accuracy: 89.69%
# Epoch [54/60] Batch [400/1250] Loss: 0.2776 Accuracy: 90.09%
# Epoch [54/60] Batch [600/1250] Loss: 0.2733 Accuracy: 90.38%
# Epoch [54/60] Batch [800/1250] Loss: 0.2696 Accuracy: 90.51%
# Epoch [54/60] Batch [1000/1250] Loss: 0.2682 Accuracy: 90.59%
# Epoch [54/60] Batch [1200/1250] Loss: 0.2669 Accuracy: 90.61%
#
# --- Epoch [54/60] Complete | Train Loss: 0.2679 | Train Acc: 90.58% | Val Loss: 0.4153 | Val Acc: 86.00% ---
#
# Epoch [55/60] Batch [200/1250] Loss: 0.2729 Accuracy: 90.34%
# Epoch [55/60] Batch [400/1250] Loss: 0.2664 Accuracy: 90.82%
# Epoch [55/60] Batch [600/1250] Loss: 0.2640 Accuracy: 90.79%
# Epoch [55/60] Batch [800/1250] Loss: 0.2624 Accuracy: 90.80%
# Epoch [55/60] Batch [1000/1250] Loss: 0.2629 Accuracy: 90.77%
# Epoch [55/60] Batch [1200/1250] Loss: 0.2624 Accuracy: 90.79%
#
# --- Epoch [55/60] Complete | Train Loss: 0.2634 | Train Acc: 90.74% | Val Loss: 0.4145 | Val Acc: 86.09% ---
#
# Epoch [56/60] Batch [200/1250] Loss: 0.2878 Accuracy: 90.09%
# Epoch [56/60] Batch [400/1250] Loss: 0.2745 Accuracy: 90.39%
# Epoch [56/60] Batch [600/1250] Loss: 0.2745 Accuracy: 90.37%
# Epoch [56/60] Batch [800/1250] Loss: 0.2735 Accuracy: 90.40%
# Epoch [56/60] Batch [1000/1250] Loss: 0.2724 Accuracy: 90.47%
# Epoch [56/60] Batch [1200/1250] Loss: 0.2719 Accuracy: 90.45%
#
# --- Epoch [56/60] Complete | Train Loss: 0.2714 | Train Acc: 90.47% | Val Loss: 0.4132 | Val Acc: 86.15% ---
#
# Epoch [57/60] Batch [200/1250] Loss: 0.2686 Accuracy: 90.69%
# Epoch [57/60] Batch [400/1250] Loss: 0.2626 Accuracy: 90.73%
# Epoch [57/60] Batch [600/1250] Loss: 0.2615 Accuracy: 90.82%
# Epoch [57/60] Batch [800/1250] Loss: 0.2646 Accuracy: 90.64%
# Epoch [57/60] Batch [1000/1250] Loss: 0.2649 Accuracy: 90.64%
# Epoch [57/60] Batch [1200/1250] Loss: 0.2641 Accuracy: 90.61%
#
# --- Epoch [57/60] Complete | Train Loss: 0.2630 | Train Acc: 90.66% | Val Loss: 0.4136 | Val Acc: 86.20% ---
#
# Epoch [58/60] Batch [200/1250] Loss: 0.2709 Accuracy: 90.14%
# Epoch [58/60] Batch [400/1250] Loss: 0.2655 Accuracy: 90.42%
# Epoch [58/60] Batch [600/1250] Loss: 0.2662 Accuracy: 90.46%
# Epoch [58/60] Batch [800/1250] Loss: 0.2639 Accuracy: 90.58%
# Epoch [58/60] Batch [1000/1250] Loss: 0.2616 Accuracy: 90.69%
# Epoch [58/60] Batch [1200/1250] Loss: 0.2607 Accuracy: 90.77%
#
# --- Epoch [58/60] Complete | Train Loss: 0.2613 | Train Acc: 90.75% | Val Loss: 0.4125 | Val Acc: 86.39% ---
#
# Epoch [59/60] Batch [200/1250] Loss: 0.2677 Accuracy: 90.86%
# Epoch [59/60] Batch [400/1250] Loss: 0.2634 Accuracy: 90.95%
# Epoch [59/60] Batch [600/1250] Loss: 0.2669 Accuracy: 90.81%
# Epoch [59/60] Batch [800/1250] Loss: 0.2636 Accuracy: 90.85%
# Epoch [59/60] Batch [1000/1250] Loss: 0.2626 Accuracy: 90.81%
# Epoch [59/60] Batch [1200/1250] Loss: 0.2621 Accuracy: 90.80%
#
# --- Epoch [59/60] Complete | Train Loss: 0.2622 | Train Acc: 90.80% | Val Loss: 0.4128 | Val Acc: 86.29% ---
#
# Epoch [60/60] Batch [200/1250] Loss: 0.2801 Accuracy: 90.02%
# Epoch [60/60] Batch [400/1250] Loss: 0.2737 Accuracy: 90.45%
# Epoch [60/60] Batch [600/1250] Loss: 0.2703 Accuracy: 90.62%
# Epoch [60/60] Batch [800/1250] Loss: 0.2698 Accuracy: 90.67%
# Epoch [60/60] Batch [1000/1250] Loss: 0.2647 Accuracy: 90.82%
# Epoch [60/60] Batch [1200/1250] Loss: 0.2628 Accuracy: 90.84%
#
# --- Epoch [60/60] Complete | Train Loss: 0.2621 | Train Acc: 90.85% | Val Loss: 0.4129 | Val Acc: 86.26% ---

# %%
epochs = range(1, NUM_EPOCHS + 1)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# --- Loss curves ---
# a decreasing loss means the model is getting better at minimizing its
# mistakes. the gap between train and val loss indicates overfitting —
# if val loss starts rising while train loss keeps falling, the model
# is memorizing training data rather than learning general patterns.
ax1.plot(epochs, history['train_loss'], label='Train Loss', color='steelblue')
ax1.plot(epochs, history['val_loss'],   label='Val Loss',   color='tomato')
ax1.set_title('Loss Curves')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()
ax1.grid(True, alpha=0.3)

# --- Accuracy curves ---
# a rising accuracy means the model is classifying more images correctly.
# ideally both curves climb together — a large train/val gap here also
# signals overfitting.
ax2.plot(epochs, history['train_acc'], label='Train Acc', color='steelblue')
ax2.plot(epochs, history['val_acc'],   label='Val Acc',   color='tomato')
ax2.set_title('Accuracy Curves')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy (%)')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.suptitle('Training History', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

print(f"Best val accuracy: {max(history['val_acc']):.2f}% "
      f"(epoch {history['val_acc'].index(max(history['val_acc'])) + 1})")
# Out:
# Best val accuracy: 86.39% (epoch 58)

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

# collect all predictions on the validation set in one pass.
# we run the full val set through the model and store every predicted
# label and every true label so we can compare them all at once.
model.eval()
all_preds = []
all_targets = []

with torch.no_grad():
    for images, labels in val_loader:
        images = images.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, dim=1)
        all_preds.extend(predicted.cpu().tolist())
        all_targets.extend(labels.tolist())

# build the confusion matrix.
# each row is a true class, each column is a predicted class.
# a perfect model would have all values on the diagonal and zeros everywhere else.
# off-diagonal values reveal which classes the model confuses with each other.
class_names = list(val_dataset.label_to_idx.keys())
cm = confusion_matrix(all_targets, all_preds)

fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names,
    ax=ax
)
ax.set_title('Confusion Matrix (Validation Set)', fontsize=14, fontweight='bold')
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# per-class accuracy — the diagonal divided by row totals.
# this shows which specific classes the model struggles with most.
print('\nPer-class accuracy:')
for i, name in enumerate(class_names):
    class_acc = cm[i, i] / cm[i].sum() * 100
    print(f'  {name:<12}: {class_acc:.1f}%')
# Out:
# Per-class accuracy:
#   airplane    : 88.7%
#   automobile  : 92.4%
#   bird        : 79.9%
#   cat         : 74.2%
#   deer        : 84.3%
#   dog         : 78.0%
#   frog        : 88.7%
#   horse       : 89.1%
#   ship        : 93.9%
#   truck       : 93.4%

# %%
torch.save({
    # the model's learned weights — the "knowledge"
    'model_state_dict': model.state_dict(),
    
    # the optimizer state — saved in case we want to resume training
    # later rather than starting from scratch
    'optimizer_state_dict': optimizer.state_dict(),
    
    # metadata about this training run, useful for keeping track
    # of what produced this version of the model
    'epoch': NUM_EPOCHS,
    'train_acc': 86.22,
    'val_acc': 85.18,
    'notes': 'mild augmentation, cosine annealing, 60 epochs'
}, 'cifar_model_86_21.pth')

print("Model saved.")
# Out:
# Model saved.

# %%
from torchinfo import summary

# the input_size argument tells torchinfo what shape of tensor to trace
# through the model. format is (batch_size, channels, height, width).
# we use batch_size=1 here since we just want to see the layer shapes,
# not actually process a real batch.
summary(model, input_size=(1, 3, 32, 32))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CIFARClassifier                          [1, 10]                   --
# ├─Conv2d: 1-1                            [1, 32, 32, 32]           896
# ├─ReLU: 1-2                              [1, 32, 32, 32]           --
# ├─MaxPool2d: 1-3                         [1, 32, 16, 16]           --
# ├─Conv2d: 1-4                            [1, 64, 16, 16]           18,496
# ├─ReLU: 1-5                              [1, 64, 16, 16]           --
# ├─MaxPool2d: 1-6                         [1, 64, 8, 8]             --
# ├─Conv2d: 1-7                            [1, 128, 8, 8]            73,856
# ├─ReLU: 1-8                              [1, 128, 8, 8]            --
# ├─MaxPool2d: 1-9                         [1, 128, 4, 4]            --
# ├─Flatten: 1-10                          [1, 2048]                 --
# ├─Dropout: 1-11                          [1, 2048]                 --
# ├─Linear: 1-12                           [1, 512]                  1,049,088
# ├─ReLU: 1-13                             [1, 512]                  --
# ├─Dropout: 1-14                          [1, 512]                  --
# ├─Linear: 1-15                           [1, 10]                   5,130
# ==========================================================================================
# Total params: 1,147,466
# Trainable params: 1,147,466
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 11.43
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.46
# Params size (MB): 4.59
# Estimated Total Size (MB): 5.07
# ==========================================================================================
